# %% [markdown]
# $$
# \newcommand{\mymat}[1]{
# \left[
# \begin{array}{rrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# #1
# \end{array}
# \right]
# }
# \newcommand{\myaug}[1]{
# \left[
# \begin{array}{rrr|r}
# #1
# \end{array}
# \right]
# }
# \newcommand{\myp}[1]{\left( #1 \right)}
# \newcommand{\myb}[1]{\left[ #1 \right]}
# \newcommand{\myv}[1]{\left< #1 \right>}
# \newcommand{\mys}[1]{\left\{ #1 \right\}}
# \newcommand{\myab}[1]{\left| #1 \right|}
# \newcommand{\bx}{{\bf x}}
# \newcommand{\by}{{\bf y}}
# \newcommand{\bu}{{\bf u}}
# \newcommand{\bv}{{\bf v}}
# $$

# %% [markdown]
# #Lecture 3
#
# ***
#
# <br>
#
# ##Systems of Three Equations and Three Unknowns
#
# <br>
#
# In the previous class we solved systems of two equations and two unknowns in a systematic way by transforming the linear system into an upper triangular system through **elimination** and then solving the new system by **back substitution**.  Let's look at how the process generalizes to systems of three equations and three unknowns.  After this we'll have the tools necessary to solve systems of any reasonable size.
#
# The goals here are still the same
#
# 1. Perform **elimination** to make the system look upper triangular, either by adding multiples of one row to another, or possibly by exchanging rows.
# 2. Solve the resulting upper triangular system via back substitution.
#
# ###Example 1
#
# Consider the following system
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 3x_2 + 2x_3 &=& 4 \\
# -2x_1 - 7x_2 + x_3 &=& 9 \\
# 3x_1 + 10x_2 + 9x_3 &=& 19
# \end{array}
# $$
#
# <br>
#
# The first thing we'll do is use the **pivot** in the $x_1$ position of row 1 to eliminate the $x_1$ terms in the other equations.
#
# To eliminate the $x_1$ term in row 2 we multiply the first row by $-2$ and subtract it from row 2.  To eliminate the $x_1$ term in row 3 we multiply the first row by $3$ and subtract it from row 3.
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 3x_2 + 2x_3 &=& 4 \\
#  -x_2 + 5x_3 &=& 17 \\
#  x_2 + 3x_3 &=& 7
# \end{array}
# \quad \quad
# \begin{array}{ll}
#  & \\
# R_2 \leftarrow & R_2 - (-2)R_1  \\
# R_3 \leftarrow & R_3 - 3R_1
# \end{array}
# $$
#
# <br>
#
# We've successfully eliminated all of the $x_1$ terms in rows 2 and 3.  Notice that the 1 coefficient on $x_1$ is the **pivot** in the first row and we used it to eliminate the $x_1$ terms in rows 2 and 3 with **multipliers** of $-2$ and $3$, respectively.  Recall that the multiplier is computed by
#
# <br>
#
# $$
# \textbf{multiplier} = \textbf{entry to eliminate} \div \textbf{pivot}
# $$
#
# <br>
#
# Next we want to eliminate the $x_2$ term in row 3.  Notice that we need to subtract a multiple of one of the previous rows to eliminate this term, but if we use the first equation this will put a nonzero $x_1$ term in row 3 and muck up our upper triangular form.  This means that we can really only use row 2 to do this elimination.  In fact, at this point we're pretty much done with row 1 for the elimination phase.
#
# The **pivot** in the second row is the $-1$ in front of the $x_2$ term.  To eliminate the $x_2$ in row three we multiply row 2 by $-1$ and subtract.
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 3x_2 + 2x_3 &=& 4 \\
#  -x_2 + 5x_3 &=& 17 \\
#  8x_3 &=& 24
# \end{array}
# \quad \quad
# \begin{array}{ll}
#  & \\
# & \\
# R_3 \leftarrow & R_3 - (-1)R_2
# \end{array}
# $$
#
# <br>
#
# The system is now in upper triangular form and the elimination phase is done.  The new upper triangular system is
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 3x_2 + 2x_3 &=& 4 \\
#  -x_2 + 5x_3 &=& 17 \\
#  8x_3 &=& 24
# \end{array}
# $$
#
# <br>
#
# Notice that the system has three pivots, namely $1$, $-1$, and $8$.  To solve the system for the unknowns $x_1$, $x_2$, and $x_3$ we perform back substitution.
#
# Starting with row 3 we have
#
# <br>
#
# $$
# x_3 = 24 ~/~8 = 3
# $$
#
# <br>
#
# Substituting this into row 2 and solving for $x_2$ we have
#
# <br>
#
# $$
# -x_2 + 5\myp{3} = 17 \quad \Rightarrow \quad -x_2 = 2 \quad \Rightarrow \quad x_2 = 2 ~~ / ~ -1 = -2
# $$
#
# <br>
#
# Substituting the values for $x_3$ and $x_2$ into row 1 and solving for $x_1$ we have
#
# <br>
#
# $$
# x_1 + 3\myp{-2} + 2\myp{3} = 4 \quad \Rightarrow \quad x_1 = 4
# $$
#
# <br>
#
# Which gives us a final solution of ${\bx} = \mymat{4 \\ -2 \\ 3}$
#
# $\square$

# %% [markdown]
# ##Gaussian Elimination and the Augmented System
#
# <br>
#
# By the way, this process of elimination to make the system upper triangular, followed by back substitution to solve the resulting system is called **Gaussian Elimination** after the great German mathematican Carl Friedrich Gauss, who invented the method in the 1800s.
#
# OK, things are starting to get awfully clunky solving the algebraic system with so many equations and unknowns.  It's time to make things nicer by formulating things with matrices and vectors.  Recall that the above system can be written in matrix equation form as
#
# <br>
#
# $$
# \mymat{
# 1 & 3 & 2 \\
# -2 & -7 & 1 \\
# 3 & 10 & 9
# }
# \mymat{x_1 \\ x_2 \\ x_3} =
# \mymat{4 \\ 9 \\ 19}
# $$
#
# <br>
#
# The beauty of the matrix formulation is that we have all of the necessary coefficients of the linear system encoded in the matrix.  Their position in the matrix tells us which equation and unknown each coefficient corresponds to, i.e. each row of the matrix refers to an equation in the orginal system, and each column in the matrix corresponds to one of the unknown variables.  We should be able to perform exactly the same operations on the matrix and right-hand side vector that we performed on the system of equations.
#
# In fact, since we know which column corresponds to which unknown, that vector of variables is kind of in the way too.  Let's get rid of it.
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# -2 & -7 & 1 & 9 \\
# 3 & 10 & 9 & 19
# }
# $$
#
# <br>
#
# The first three columns of the table represent the original coefficient matrix.  The last column represents the rhs vector.  The vertical line is there to tell us where the separation between matrix and rhs vector is.
#
# We can now proceed as before with the elimination phase.  Nothing has really changed except the way we have written down the linear system.  We choose the $1$ in the $(1,1)$ position of the coefficient matrix as the first pivot and use it to eliminate the nonzero coefficients beneath it in the first column.  We have
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# -2 & -7 & 1 & 9 \\
# 3 & 10 & 9 & 19
# }
# \quad \quad
# \begin{array}{l&l}
#  & \\
# R_2 \leftarrow & R_2 - (-2)R_1  \\
# R_3 \leftarrow & R_3 - 3R_1
# \end{array}
# \quad \quad
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 1 & 3 & 7
# }
# $$
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 1 & 3 & 7
# }
# \quad \quad
# \begin{array}{l&l}
#  & \\
#  & \\
#  R_3 \leftarrow & R_3 - (-1)R_2
# \end{array}
# \quad \quad
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 0 & 8 & 24
# }
# $$
#
# <br>
#
# which gives us the upper triangular augmented system
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 0 & 8 & 24
# }
# $$
#
# <br>
#
# Note that in this form it's even easier to identify the pivots $1$, $-1$, $8$.  They're sitting right there on the diagonal of the matrix.
#
# After the elimination phase we've successfully transformed the original linear system into an upper triangular system with the same solution.  In other words,
#
# <br>
#
# $$
# A\bx = {\bf b} \quad \quad \Rightarrow \quad \quad U \bx = {\bf c}
# $$
#
# <br>
#
# The back substitution phase can easily be carried out on the augmented system.  We typically write it in the following condensed form.  Note that although it's written in the usual order, it's computed and read from the bottom up.
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 0 & 8 & 24
# }
# \quad \Rightarrow \quad
# \bx =
# \mymat{
# (4 - 3(-2) - 2(3)) / 1 = 4 \\
# (17 - 5(3)) / -1 = -2 \\
# 24 / 8 = 3 \\
# } =
# \mymat{
# 4 \\
# -2 \\
# 3
# }
# $$
#
# <br>

# %% [markdown]
# ###Example 2
#
# Let's solve the following linear system using elimination and back substitution on the augmented system.
#
# <br>
#
# $$
# \begin{array}{rcl}
# 2x_1 - x_2 + 3x_3 &=& 6 \\
# 4x_1 + 7x_3 &=& 11 \\
# 2x_1 + x_2 + 8x_3 &=& 9
# \end{array}
# $$
#
# <br>
#
# The corresponding augmented system is
#
# <br>
#
# $$
# \myaug{
# 2 & -1 & 3 & 6 \\
# 4 & 0  & 7 & 11 \\
# 2 & 1 & 8 & 9
# }
# $$
#
# <br>
#
# The pivot in the first row is the $2$ in the $(1,1)$ position.  Eliminating the nonzeros in the column below the pivot we have
#
# <br>
#
# $$
# \myaug{
# 2 & -1 & 3 & 6 \\
# 4 & 0  & 7 & 11 \\
# 2 & 1 & 8 & 9
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# R_2 \leftarrow & R_2 - 2R_1 \\
# R_3 \leftarrow & R_3 - R_1
# \end{array}
# \quad \quad
# \myaug{
# 2 & -1 & 3 & 6 \\
# 0 & 2  & 1 & -1 \\
# 0 & 2 & 5 & 3
# }
# $$
#
# <br>
#
# The pivot in the second row is the $2$ in the $(2,2)$ position.  Eliminating the nonzeros in the column below the pivot we have
#
# <br>
#
# $$
# \myaug{
# 2 & -1 & 3 & 6 \\
# 0 & 2  & 1 & -1 \\
# 0 & 2 & 5 & 3
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# & \\
# R_3 \leftarrow & R_3 - R_2
# \end{array}
# \quad \quad
# \myaug{
# 2 & -1 & 3 & 6 \\
# 0 & 2  & 1 & -1 \\
# 0 & 0 & 4 & 4
# }
# $$
#
# <br>
#
# At this point the coefficient matrix is upper triangular and the elimination phase is complete.  Performing back substituion we have
#
# <br>
#
# $$
# \myaug{
# 2 & -1 & 3 & 6 \\
# 0 & 2  & 1 & -1 \\
# 0 & 0 & 4 & 4
# }
# \quad \Rightarrow \quad
# \bx =
# \mymat{
# (6 +1(-1) - 3(1)) / 2 = 1 \\
# (-1 - 1(1)) / 2 = -1 \\
# 4 / 4 = 1
# } =
# \mymat{
# 1 \\
# -1 \\
# 1
# }
# $$

# %% [markdown]
# OK, so that's what the solution process looks like on a nice happy solution with a unique solution.  Let's look at a more complicated case.
#
# ###Example 3
#
# Use an augmented matrix equation to solve the following linear system:
#
# <br>
#
# $$
# \begin{array}{rcl}
# 2x_1 + 4x_2 - 2x_3 &=& -12 \\
# 2x_1 + 4x_2 + 2x_3 &=& 0 \\
# x_1 - x_2 + x_3 &=& 6
# \end{array}
# $$
#
# <br>
#
# Writing the linear system in it's aumented matrix form we have
#
# <br>
#
# $$
# \myaug{
# 2 & 4 & -2 & -12 \\
# 2 & 4 &  2 & 0 \\
# 1 & -1 & 1 & 6
# }
# $$
#
# <br>
#
# Using the 2 in the (1,1) position as the pivot we eliminate everything under it in the first column:
#
# <br>
#
# $$
# \myaug{
# 2 & 4 & -2 & -12 \\
# 2 & 4 &  2 & 0 \\
# 1 & -1 & 1 & 6
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# R_2 \leftarrow & R_2 - R_1 \\
# R_3 \leftarrow & R_3 - \frac{1}{2}R_1
# \end{array}
# \quad \quad
# \myaug{
# 2 & 4 & -2 & -12 \\
# 0 & 0 &  4 & 12 \\
# 0 & -3 & 2 & 12
# }
# $$
#
# <br>
#
# OK, we've encountered our first hitch.  Normally we'd want to use the entry in the (2,2) position as the pivot to eliminate the (3,2) entry, but the (2,2) entry is zero, so it can't be a pivot.  This is easily fixed by just swapping rows 2 and 3 in the **entire** augmented system (i.e. swap the rhs elements as well).
#
# <br>
#
# $$
# \myaug{
# 2 & 4 & -2 & -12 \\
# 0 & 0 &  4 & 12 \\
# 0 & -3 & 2 & 12
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# R_2 \leftrightarrow R_3 &  \\
#  &
#  \end{array}
# \quad \quad
# \myaug{
# 2 & 4 & -2 & -12 \\
# 0 & -3 & 2 & 12 \\
# 0 & 0 &  4 & 12
# }
# $$
#
# <br>
#
# After the row swap the augmented system is in upper triangular form and we're ready to do back substitution.  We have
#
# <br>
#
# $$
# \myaug{
# 2 & 4 & -2 & -12 \\
# 0 & -3 & 2 & 12 \\
# 0 & 0 &  4 & 12
# }
# \quad \Rightarrow \quad
# \bx =
# \mymat{
# (-12 -4(-2) + 2(3)) / 2 = 1 \\
# (12 - 2(3)) / (-3) = -2 \\
# 12 / 4 = 3
# } =
# \mymat{
# 1 \\
# -2 \\
# 3
# }
# $$
#
# <br>
#
# ###Example 4
#
# Use an augmented matrix equation to solve the following linear system:
#
# <br>
#
# $$
# \begin{array}{rcl}
# 2x_1  +4x_3 &=& -2 \\
#  x_1 + 2x_2 - x_3 &=& 2 \\
# 4x_1 + 4x_2 + 2x_3 &=& 0
# \end{array}
# $$
#
# <br>
#
# Writing the linear system in it's aumented matrix form we have
#
# <br>
#
# $$
# \myaug{
# 2 & 0 &  4 & -2 \\
# 1 & 2 & -1 & 2 \\
# 4 & 4 &  2 & 0
# }
# $$
#
# <br>
#
# Using the 2 in the first row as the pivot we eliminate everything under it in the first column:
#
# <br>
#
# $$
# \myaug{
# 2 & 0 &  4 &-2 \\
# 1 & 2 & -1 & 2 \\
# 4 & 4 &  2 & 0
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# R_2 \leftarrow & R_2 - \frac{1}{2}R_1 \\
# R_3 \leftarrow & R_3 - 2R_1
# \end{array}
# \quad \quad
# \myaug{
# 2 & 0 &  4 & -2 \\
# 0 & 2 & -3 & 3 \\
# 0 & 4 &  -6 & 4
# }
# $$
#
# <br>
#
# Next we use the 2 in the (2,2) as the pivot to eliminate the entry in the (3,2) position.  We have
#
# <br>
#
# $$
# \myaug{
# 2 & 0 &  4 & -2 \\
# 0 & 2 & -3 & 3 \\
# 0 & 4 &  -6 & 4
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# & \\
# R_3 \leftarrow & R_3 - 2R_2
# \end{array}
# \quad \quad
# \myaug{
# 2 & 0 &  4 & -2 \\
# 0 & 2 & -3 & 3 \\
# 0 & 0 &  0 & -2
# }
# $$
#
# <br>
#
# Notice that we've reduced the augmented system to upper triangular form, but we only have 2 pivots in the coefficient matrix, namely the 2 in the (1,1) position and the 2 in the (2,2) position.  Since the system is 3x3 and there are not three pivots, this should tell you that something is up.
#
# The third row in the augmented system tells us that
#
# <br>
#
# $$
# 0x_1 + 0x_2 + 0x_3 = -2
# $$
#
# <br>
#
# Of course this is impossible, so the system has **no solution**.
#
# Let's do one more.
#
# ###Example 5
#
# Use an augmented matrix equation to solve the following linear system:
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 2x_2 - 3x_3 &=& 1 \\
# 2x_1 + 5x_2 - 8x_3 &=& 4 \\
# 3x_1 + 8x_2 - 13x_3 &=& 7
# \end{array}
# $$
#
# <br>
#
# Writing the linear system in it's aumented matrix form we have
#
# <br>
#
# $$
# \myaug{
# 1 & 2 & -3 & 1 \\
# 2 & 5 & -8 & 4 \\
# 3 & 8 & -13 & 7
# }
# $$
#
# <br>
#
# Using the 1 in the first row as the pivot we eliminate everything under it in the first column:
#
# <br>
#
# $$
# \myaug{
# 1 & 2 & -3 & 1 \\
# 2 & 5 & -8 & 4 \\
# 3 & 8 & -13 & 7
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# R_2 \leftarrow & R_2 - 2R_1 \\
# R_3 \leftarrow & R_3 - 3R_1
# \end{array}
# \quad \quad
# \myaug{
# 1 & 2 & -3 & 1 \\
# 0 & 1 & -2 & 2 \\
# 0 & 2 & -4 & 4
# }
# $$
#
# <br>
#
# Next we use the 2 as the pivot in the $(2,2)$ position to eliminate the $2$ below it.
#
# <br>
#
# $$
# \myaug{
# 1 & 2 & -3 & 1 \\
# 2 & 5 & -8 & 4 \\
# 3 & 8 & -13 & 7
# }
# \quad \quad
# \begin{array}{ll}
# & \\
# & \\
# R_3 \leftarrow & R_3 - 2R_2
# \end{array}
# \quad \quad
# \myaug{
# 1 & 2 & -3 & 1 \\
# 0 & 1 & -2 & 2 \\
# 0 & 0 &  0 & 0
# }
# $$
#
# <br>
#
# Again, the elimination phase produces a coefficient matrix that only has 2 pivots, indicating that something is wrong.  But this time the third row corresponds to
#
# <br>
#
# $$
# 0x_1 + 0x_2 + 0x_3 = 0
# $$
#
# <br>
#
# Of course, any set of values for $x_1$, $x_2$, and $x_3$ will satisfy the third equation, so there is no conflict like there was in the previous example.
#
# This is an instance of a linear system that has an infinite number of solutions.  To see this, notice that we can write the augmented system as a system of equations of the following form
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 2x_2 &=& 1 + 3x_3 \\
# x_2 &=& 2 + 2x_3
# \end{array}
# $$
#
# <br>
#
# When we can write some of the variables in terms of one or more of the other variables we give the variables particular names.  The variables on the left side of the equation (this time $x_1$ and $x_2$) are called **basic variables**, and the variables on the right-hand side (this time $x_3$) are called **free variables**.  Notice that the basic variables correspond to the columns in the upper triangular system that have pivots, and the free variables correspond to the columns that do not have pivots.
#
#
# We can now write the solution in a more general and useful form. Substituting $x_2$ in terms of $x_3$ into the first equation gives
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1 + 2\myp{2+2x_3} &=& 1 + 3x_3 \\
# x_2 &=& 2 + 2x_3
# \end{array}
# \quad \quad \Rightarrow \quad\quad
# \begin{array}{rcl}
# x_1  &=& -3  - x_3 \\
# x_2 &=& 2 + 2x_3 \\
# x_3 &=& x_3
# \end{array}
# $$
#
# <br>
#
# Writing the third equation as $x_3 = x_3$ might look kind of silly, but it puts the solution in the form that we'd typically expect if we had solution values for each of the $x_i$'s.
#
# The next step is more of a notational thing.  We replace all instances of $x_3$ on the right-hand side of the system with a **parameter** like $t$ or $s$, like so
#
# <br>
# $$
# \begin{array}{rcl}
# x_1  &=& -3  - t \\
# x_2 &=& 2 + 2t \\
# x_3 &=& t
# \end{array}
# $$
# <br>
#
# Now, we can generate solutions to the linear system by choosing any value of the the paramter $t$ that we like.  We replace $x_3$ by $t$ because at this point it doesn't really matter that the paramter corresponds to a particular one of the original variables.  We just care that we're free to pick it.
#
# Notice that we can write the solution in vector form as follows
#
# <br>
#
# $$
# \begin{array}{rcl}
# x_1  &=& -3  - t \\
# x_2 &=& 2 + 2t \\
# x_3 &=& 0 + t
# \end{array}
# \quad \quad \Rightarrow \quad \quad
# \bx =
# \mymat{-3 \\ 2 \\ 0} + t\mymat{-1 \\ 2 \\ 1}
# $$

# %% [markdown]
# <br>
#
# Let's check that we've come up with the correct **general solution** by choosing a few values of $t$ and checking that the resulting solution vectors satisfy the original system.  Recall that the original system written in matrix form was
#
# <br>
#
# $$
# A\bx = {\bf b} \quad \Leftrightarrow \quad
# \mymat{
# 1 & 2 & -3 \\
# 2 & 5 & -8 \\
# 3 & 8 & -13
# }
# \mymat{x_1 \\ x_2 \\ x_3} =
# \mymat{1 \\ 4 \\ 7}
# $$
#
# <br>
#
# Choosing $t = 0$ and $t = 1$ gives the following solutions
#
# <br>
#
# $$
# \bx =
# \mymat{
# -3 \\ 2 \\ 0
# }
# \quad \quad \textrm{and} \quad \quad
# \by =
# \mymat{-4 \\ 4 \\ 1}
# $$
#
# <br>
#
# Multiplying the coefficient matrix $A$ by each of these vectors gives
#
# <br>
#
# $$
# \mymat{
# 1 & 2 & -3 \\
# 2 & 5 & -8 \\
# 3 & 8 & -13
# }
# \mymat{-3 \\ 2 \\ 0} =
# \mymat{
# 1(-3) + 2(2) - 3(0) \\
# 2(-3) + 5(2) - 8(0) \\
# 3(-3) + 8(2) - 13(0)
# } =
# \mymat{
# 1 \\
# 4 \\
# 7
# }
# \quad \checkmark
# $$
#
# <br>
#
# $$
# \mymat{
# 1 & 2 & -3 \\
# 2 & 5 & -8 \\
# 3 & 8 & -13
# }
# \mymat{-4 \\ 4 \\ 1} =
# \mymat{
# 1(-4) + 2(4) - 3(1) \\
# 2(-4) + 5(4) - 8(1) \\
# 3(-4) + 8(4) - 13(1)
# } =
# \mymat{
# 1 \\
# 4 \\
# 7
# }
# \quad \checkmark
# $$
#
# <br>
#
# Of course we could pick **any** value of the parameter $t$ that we like to generate a new solution that works.  Therefore we say that the system has an **infinite** number of solutions.

# %% [markdown]
# ##Classifying Linear Systems
#
# <br>
#
# OK, so we did a bunch of different examples and we saw a few specific cases come up.  Let's break them up into two categories.
#
# * **Category 1**: The system has exactly one solution
# * **Category 2**: The system has either no solutions or infintely many solutions
#
# The two categories can be distiguished by the upper triangular system that results from the elimination process.  Let's look at these for a couple of the examples done above.
#
# ###Category 1 Example
#
# <br>
#
# In **Example 1** the linear system yielded exactly one solution.  The augmented system after the elimination phase looked as follows.
#
# <br>
#
# $$
# \myaug{
# 1 & 3 & 2 & 4 \\
# 0 & -1 & 5 & 17 \\
# 0 & 0 & 8 & 24
# }
# $$
#
# <br>
#
# The main characteristic of this upper triangular system is that the coefficient matrix has a pivot in every column, allowing us to solve exactly for each of the variables during the back substitution phase.  When this happens the system has exactly one solution and we say that the linear system is **nonsingular**.
#
# <br>
#
# ###Category 2 Example
#
# <br>
#
# **Example 4** and **Example 5** had no solution and infinitely many solutions, respectively.  The augmented systems after the elimination phase for these two examples looked as follows:
#
# <br>
#
# $$
# \myaug{
# 2 & 0 &  4 & -2 \\
# 0 & 2 & -3 & 3 \\
# 0 & 0 &  0 & -2
# }
# \quad \quad \textrm{and} \quad \quad
# \myaug{
# 1 & 2 & -3 & 1 \\
# 0 & 1 & -2 & 2 \\
# 0 & 0 &  0 & 0
# }
# $$
#
# <br>
#
# In each of these cases the coefficient matrices after elimination failed to have a pivot in each column.  Whether the system had no solution of infintely many solutions depended on the rhs vector.  In any case, when this happens we lump both cases into the same catgory and describe the system as **singular**.
#
# Notice that we could have determined which general category the system fell into without actually knowing the right-hand side vectors.  For this reason we also categorize the **matrix** $A$ as singular or nonsingular.  We can also test for the nonsingularness of $A$ by performing the elimination process without the rhs vector.
#
# **Note**: The names **singular** and **nonsingular** are kind of funny and a little counterintuitive.  But once you spend enough time in linear algebra they start to make sense.  The word **singular** kind of means *special* or *unusual*.  Why then is it that systems that have no solution or infintiely many solutions are *special*?  The answer is that it's because they're incredibly rare.  If you were to randomly generate square matrices, the chance that you would generate one that, given a rhs vector, has no solution or infintiely many solutions is basically zero.  This is not to say that **singular** systems never occur in practice.  There are many science and engineering problems that yield singular matrices.
